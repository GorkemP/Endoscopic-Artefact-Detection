# %%
import testTimeAugmentation
import function
import os
import shutil
import argparse
import ensembleOptions
from mainTTA import tta
from imutils import paths
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/externals/joblib/__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-dc652ad3821f> in <module>()
#       1 import testTimeAugmentation
# ----> 2 import function
#       3 import os
#       4 import shutil
#       5 import argparse
#
# /home/ws2080/Desktop/codes/ensembleObjectDetection/TestTimeAugmentation/function.py in <module>()
# ----> 1 from clodsa.augmentors.augmentorFactory import createAugmentor
# ...

# %%
pathImg = r'/home/ws2080/Dekstop/data/training/test'

# %%
option = "consensus"

# %%
custom_retinanet = testTimeAugmentation.custom_retinanet()

# %%
myTechniques = [ "vflip", "hflip", "hvflip", "none"]

# %%
tta(custom_retinanet,myTechniques,pathImg,option,0.4)
